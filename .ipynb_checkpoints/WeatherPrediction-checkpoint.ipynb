# %%
import pandas as pd
import matplotlib.pyplot as plt
import keras.preprocessing
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\truma\anaconda3\envs\condapy\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def parse_input_data(data_filename):
    input_data = pd.read_csv(data_filename, header=0, skiprows=[1])
    input_data = input_data.iloc[::-1] # reverse data order

    selected_columns = ['altimeter', 'air_temp', 'relative_humidity', 'wind_speed', 'wind_direction',
                        'visibility', 'sea_level_pressure']

    # Take only valid columns and make a copy
    weather_data = input_data[selected_columns].copy()
    print(weather_data)
    # weather_data.set_index('date_time', inplace=True)
    weather_data.index = input_data['date_time']
    # weather_data.index = pd.to_datetime(input_data['date_time'])
    print(input_data['date_time'])
    print(weather_data)
    print(weather_data.index)
    values = {'wind_speed': 0, 'wind_direction': 0}
    weather_data.fillna(value=values, inplace=True)
    weather_data = weather_data.interpolate()
    weather_data = weather_data.round({'air_temp': 2, 'sea_level_pressure': 1})

    weather_data.dropna(subset=["sea_level_pressure"], inplace=True)

    # check if any values are still NaN
    if weather_data.isnull().values.any():
        null_columns = weather_data.columns[weather_data.isna().any()].tolist()
        weather_data.to_csv("weather_data_check_FAIL.csv")
        raise Exception(f"Columns are null in weather_data: {*null_columns,} ")
    else:
        print("Successfully parsed data")
        try:
            weather_data.to_csv("weather_data_check.csv")
        except PermissionError:
            print("Cannot write weather_data to file")
        return weather_data


def plot_all_data(weather_data):

    weather_data_daily_mean = weather_data.groupby(weather_data.index.to_period('M')).mean(numeric_only=True)
    print(weather_data_daily_mean)
    for column in weather_data.columns:
        plt.figure(figsize=(20, 6))
        weather_data_daily_mean[column].plot()
        plt.title(column)

        plt.show()

# %%
weather_data = parse_input_data("data/KVNY_1997-2023.csv")
# Out:
#         altimeter  air_temp  relative_humidity  wind_speed  wind_direction  \
# 246656      30.00     69.80              22.88       11.50           350.0
# 246655      30.01     73.40              17.48       10.36           350.0
# 246654      29.99     75.20              17.72        9.22           360.0
# 246653      29.93     61.00              83.31        9.22           200.0
# 246652      29.92     62.10              89.59        3.44           130.0
# ...           ...       ...                ...         ...             ...
# 4           30.09     55.04              86.49        0.00             0.0
# 3           30.10     55.94              83.71        0.00             0.0
# 2           30.09     55.40              87.66        3.45           120.0
# 1           30.09     55.94              83.71        3.45           130.0
# 0           30.09     55.04              86.49        3.45           250.0
#
#         visibility  sea_level_pressure
# 246656        20.0                 NaN
# 246655        30.0                 NaN
# 246654        25.0                 NaN
# 246653        10.0              1013.1
# 246652         2.0              1012.4
# ...            ...                 ...
# 4              5.0              1018.7
# 3              5.0              1018.9
# 2              4.0                 NaN
# 1              4.0              1018.6
# 0              4.0              1018.5
#
# [246657 rows x 7 columns]
# 246656    04/12/97-04:45PM
# 246655    04/12/97-05:50PM
# 246654    04/12/97-06:45PM
# 246653    05/05/98-06:55PM
# 246652    07/14/98-12:50PM
#                 ...
# 4         12/30/23-04:51AM
# 3         12/30/23-05:51AM
# 2         12/30/23-06:46AM
# 1         12/30/23-06:51AM
# 0         12/30/23-07:51AM
# Name: date_time, Length: 246657, dtype: object
#                   altimeter  air_temp  relative_humidity  wind_speed  \
# date_time
# 04/12/97-04:45PM      30.00     69.80              22.88       11.50
# 04/12/97-05:50PM      30.01     73.40              17.48       10.36
# 04/12/97-06:45PM      29.99     75.20              17.72        9.22
# 05/05/98-06:55PM      29.93     61.00              83.31        9.22
# 07/14/98-12:50PM      29.92     62.10              89.59        3.44
# ...                     ...       ...                ...         ...
# 12/30/23-04:51AM      30.09     55.04              86.49        0.00
# 12/30/23-05:51AM      30.10     55.94              83.71        0.00
# 12/30/23-06:46AM      30.09     55.40              87.66        3.45
# 12/30/23-06:51AM      30.09     55.94              83.71        3.45
# 12/30/23-07:51AM      30.09     55.04              86.49        3.45
#
#                   wind_direction  visibility  sea_level_pressure
# date_time
# 04/12/97-04:45PM           350.0        20.0                 NaN
# 04/12/97-05:50PM           350.0        30.0                 NaN
# 04/12/97-06:45PM           360.0        25.0                 NaN
# 05/05/98-06:55PM           200.0        10.0              1013.1
# 07/14/98-12:50PM           130.0         2.0              1012.4
# ...                          ...         ...                 ...
# 12/30/23-04:51AM             0.0         5.0              1018.7
# 12/30/23-05:51AM             0.0         5.0              1018.9
# 12/30/23-06:46AM           120.0         4.0                 NaN
# 12/30/23-06:51AM           130.0         4.0              1018.6
# 12/30/23-07:51AM           250.0         4.0              1018.5
#
# [246657 rows x 7 columns]
# Index(['04/12/97-04:45PM', '04/12/97-05:50PM', '04/12/97-06:45PM',
#        '05/05/98-06:55PM', '07/14/98-12:50PM', '07/14/98-01:05PM',
#        '07/14/98-01:50PM', '07/14/98-02:00PM', '07/14/98-02:50PM',
#        '07/14/98-03:50PM',
#        ...
#        '12/30/23-12:51AM', '12/30/23-01:51AM', '12/30/23-02:51AM',
#        '12/30/23-03:25AM', '12/30/23-03:51AM', '12/30/23-04:51AM',
#        '12/30/23-05:51AM', '12/30/23-06:46AM', '12/30/23-06:51AM',
#        '12/30/23-07:51AM'],
#       dtype='object', name='date_time', length=246657)
# Successfully parsed data

# %%
print(weather_data.dtypes)
weather_data = weather_data.copy()
split_fraction = .75
train_split = int(split_fraction * int(weather_data.shape[0]))
print(train_split)
past = 120
future = 12
learning_rate = 0.001
batch_size = 256
epochs = 10
step = 1

def normalize(data, train_split):
    data_mean = data[:train_split].mean(numeric_only=True, axis=0)
    data_std = data[:train_split].std(numeric_only=True, axis=0)
    return (data - data_mean) / data_std

weather_data_normalized = normalize(weather_data, train_split)
print(weather_data_normalized)
train_data = weather_data_normalized.iloc[0: train_split]
# print("Train data")
# print(train_data)
val_data = weather_data_normalized.iloc[train_split:]
# print("Val data")
# print(val_data)

start = past + future
end = start + train_split

x_train = train_data[weather_data.columns].values.astype(np.float)
# print("x_train")
# print(x_train)
y_train = weather_data_normalized.iloc[start:end][['air_temp']]
# print("y_train")
# print(y_train)

sequence_length = int(past / step)

dataset_train = keras.preprocessing.timeseries_dataset_from_array(x_train,
                                                                  y_train,
                                                                  sequence_length=sequence_length,
                                                                  sampling_rate=step,
                                                                  batch_size=batch_size)

x_end = len(val_data) - past - future

label_start = train_split + past + future

x_val = val_data.iloc[:x_end][weather_data.columns].values.astype(np.float)
y_val = weather_data_normalized.iloc[label_start:][['air_temp']]

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step,
    batch_size=batch_size,
)

for batch in dataset_train.take(1):
    inputs, targets = batch

print("Input shape:", inputs.numpy().shape)
print("Target shape:", targets.numpy().shape)

inputs = keras.layers.Input(shape=(inputs.shape[1], inputs.shape[2]))
lstm_out = keras.layers.LSTM(32)(inputs)
outputs = keras.layers.Dense(1)(lstm_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mean_squared_logarithmic_error", metrics=[keras.metrics.Accuracy()])
model.summary()

path_checkpoint = "model_checkpoint.weights.h5"
es_callback = keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0, patience=5)

modelckpt_callback = keras.callbacks.ModelCheckpoint(
    monitor="val_loss",
    filepath=path_checkpoint,
    verbose=1,
    save_weights_only=True,
    save_best_only=True,
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
    callbacks=[es_callback, modelckpt_callback],
)
# Out:
# altimeter             float64
# air_temp              float64
# relative_humidity     float64
# wind_speed            float64
# wind_direction        float64
# visibility            float64
# sea_level_pressure    float64
# dtype: object
# 184990
#                   altimeter  air_temp  relative_humidity  wind_speed  \
# date_time
# 05/05/98-06:55PM  -0.385633 -0.294572           0.998956    0.858749
# 07/14/98-12:50PM  -0.473364 -0.206766           1.247774   -0.333557
# 07/14/98-01:05PM  -0.385633 -0.166854           0.967656   -0.333557
# 07/14/98-01:50PM  -0.297901 -0.134925           1.137232   -1.043165
# 07/14/98-02:00PM  -0.297901 -0.166854           1.185570   -1.043165
# ...                     ...       ...                ...         ...
# 12/30/23-04:51AM   1.018071 -0.770321           1.124950   -1.043165
# 12/30/23-05:51AM   1.105802 -0.698480           1.014804   -1.043165
# 12/30/23-06:46AM   1.018071 -0.741585           1.171306   -0.331495
# 12/30/23-06:51AM   1.018071 -0.698480           1.014804   -0.331495
# 12/30/23-07:51AM   1.018071 -0.770321           1.124950   -0.331495
#
#                   wind_direction  visibility  sea_level_pressure
# date_time
# 05/05/98-06:55PM        0.783563    0.522224           -0.320644
# 07/14/98-12:50PM        0.164418   -2.792120           -0.495355
# 07/14/98-01:05PM       -0.985421   -3.206413           -0.445437
# 07/14/98-01:50PM       -0.985421   -2.999267           -0.395520
# 07/14/98-02:00PM       -0.985421   -2.999267           -0.345603
# ...                          ...         ...                 ...
# 12/30/23-04:51AM       -0.985421   -1.549241            1.077038
# 12/30/23-05:51AM       -0.985421   -1.549241            1.126956
# 12/30/23-06:46AM        0.075969   -1.963534            1.101997
# 12/30/23-06:51AM        0.164418   -1.963534            1.052080
# 12/30/23-07:51AM        1.225808   -1.963534            1.027121
#
# [246654 rows x 7 columns]
# C:\Users\truma\AppData\Local\Temp\ipykernel_20712\1687457972.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x_train = train_data[weather_data.columns].values.astype(np.float)
# C:\Users\truma\AppData\Local\Temp\ipykernel_20712\1687457972.py:49: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x_val = val_data.iloc[:x_end][weather_data.columns].values.astype(np.float)
# Input shape: (256, 120, 7)
# Target shape: (256, 1)
# WARNING:tensorflow:From C:\Users\truma\anaconda3\envs\condapy\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 120, 7)]          0
#
#  lstm (LSTM)                 (None, 32)                5120
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 5153 (20.13 KB)
# Trainable params: 5153 (20.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\truma\anaconda3\envs\condapy\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 723/723 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.0000e+00
# Epoch 1: val_loss improved from inf to 0.04531, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 33s 44ms/step - loss: 0.0449 - accuracy: 0.0000e+00 - val_loss: 0.0453 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.0000e+00
# Epoch 2: val_loss improved from 0.04531 to 0.04312, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 44ms/step - loss: 0.0359 - accuracy: 0.0000e+00 - val_loss: 0.0431 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 722/723 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.0000e+00
# Epoch 3: val_loss improved from 0.04312 to 0.04023, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 45ms/step - loss: 0.0344 - accuracy: 0.0000e+00 - val_loss: 0.0402 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.0000e+00
# Epoch 4: val_loss improved from 0.04023 to 0.03823, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 33s 45ms/step - loss: 0.0335 - accuracy: 0.0000e+00 - val_loss: 0.0382 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.0000e+00
# Epoch 5: val_loss improved from 0.03823 to 0.03718, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 44ms/step - loss: 0.0327 - accuracy: 0.0000e+00 - val_loss: 0.0372 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 722/723 [============================>.] - ETA: 0s - loss: 0.0320 - accuracy: 0.0000e+00
# Epoch 6: val_loss improved from 0.03718 to 0.03628, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 44ms/step - loss: 0.0320 - accuracy: 0.0000e+00 - val_loss: 0.0363 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.0000e+00
# Epoch 7: val_loss improved from 0.03628 to 0.03590, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 44ms/step - loss: 0.0314 - accuracy: 0.0000e+00 - val_loss: 0.0359 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.0000e+00
# Epoch 8: val_loss improved from 0.03590 to 0.03544, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 45ms/step - loss: 0.0310 - accuracy: 0.0000e+00 - val_loss: 0.0354 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.0000e+00
# Epoch 9: val_loss improved from 0.03544 to 0.03517, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 44ms/step - loss: 0.0306 - accuracy: 0.0000e+00 - val_loss: 0.0352 - val_accuracy: 0.0000e+00
# Epoch 10/10
# 723/723 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.0000e+00
# Epoch 10: val_loss improved from 0.03517 to 0.03479, saving model to model_checkpoint.weights.h5
# 723/723 [==============================] - 32s 45ms/step - loss: 0.0302 - accuracy: 0.0000e+00 - val_loss: 0.0348 - val_accuracy: 0.0000e+00

# %%
def denormalize(val, data, train_split):
    data_mean = data[:train_split].mean(numeric_only=True, axis=0)
    data_std = data[:train_split].std(numeric_only=True, axis=0)
    return (val * data_std['air_temp']) + data_mean['air_temp']

# %%
def visualize_loss(history, title):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(len(loss))
    plt.figure()
    plt.plot(epochs, loss, "b", label="Training loss")
    plt.plot(epochs, val_loss, "r", label="Validation loss")
    plt.title(title)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

visualize_loss(history, "Training and Validation Loss")

# %%
def show_plot(plot_data, delta, title):
    labels = ["History", "True Value", "Model Prediction Value"]
    marker = [".-", "rx", "go"]
    time_steps = list(range(-(plot_data[0].shape[0]), 0))
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, val in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10, label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future + 5) * 2])
    plt.xlabel("Time-Step")
    plt.show()
    return

# %%
for x, y in dataset_val.take(10):
    show_plot(
        [denormalize(x[0][:, 1].numpy(), weather_data, train_split), denormalize(y[0].numpy(), weather_data, train_split), denormalize(model.predict(x)[0], weather_data, train_split)],
        future,
        "Example Prediction",
    )
# Out:
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 6ms/step
